# %%
import pandas as pd
import numpy as nm

# %%
df=pd.read_csv("survey_results_public.csv")

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
#get the series(column) unique value
df['Country'].value_counts(normalize=True)
# Out:
# United States        0.236042
# India                0.102095
# Germany              0.066095
# United Kingdom       0.064642
# Canada               0.038253
#                        ...
# Timor-Leste          0.000011
# North Korea          0.000011
# Dominica             0.000011
# Chad                 0.000011
# Brunei Darussalam    0.000011
# Name: Country, Length: 179, dtype: float64

# %%
df['Age'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        14.0
# 1        19.0
# 2        28.0
# 3        22.0
# 4        30.0
#          ...
# 88878     NaN
# 88879     NaN
# 88880     NaN
# 88881     NaN
# 88882    18.0
# Name: Age, Length: 88883, dtype: float64>

# %%
df['BetterLife'].value_counts()
# Out:
# Yes    54938
# No     31331
# Name: BetterLife, dtype: int64

# %%
#This code isn’t part of our analysis, it’s just an instruction that tells our Jupyter Notebook to display our charts inline,
#right in the notebook we’re working in.

# %matplotlib inline
df['SocialMedia'].value_counts().plot(kind="bar")
#df['Age'].value_counts().plot(kind="bar")

# %%
said_no = df[df['BetterLife'] == 'No']
said_no.head(3)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 8           9                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 5                       Never
# 6                       Never
# 8  Once a month or more often
#
#                                           OpenSource  \
# 5  The quality of OSS and closed source software ...
# 6  The quality of OSS and closed source software ...
# 8  The quality of OSS and closed source software ...
#
#                                           Employment      Country Student  \
# 5                                 Employed full-time       Canada      No
# 6  Independent contractor, freelancer, or self-em...      Ukraine      No
# 8                                 Employed full-time  New Zealand      No
#
# ...

# %%
said_no.shape
# Out:
# (31331, 85)
